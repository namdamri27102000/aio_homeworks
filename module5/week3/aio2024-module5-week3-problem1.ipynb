# %% [markdown]
#                                       AI VIET NAM – AI COURSE 2024
#
#                                 Exercise: Multilayer Perceptrons (MLPs) and
#
#                                          Activation Functions
#
#                                 Dinh-Thang Duong, Yen-Linh Vu, Quang-Vinh Dinh
#
#                                         Ngày 12 tháng 11 năm 2024

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %%
random_state = 59
np.random.seed(random_state)
if torch.cuda.is_available():
    torch.cude.manual_seed(random_state)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data_path = '/kaggle/input/aio-datasets/Auto_MPG_data.csv'
dataset = pd.read_csv(data_path)

# %%
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values
print(X.shape, y.shape)
# Out:
# (392, 9) (392,)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=0.2, 
                                                      shuffle=True,
                                                      random_state=random_state,
                                                     )
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, 
                                                      test_size=0.125, 
                                                      shuffle=True,
                                                      random_state=random_state,
                                                    )

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_valid = normalizer.transform(X_valid)
X_test = normalizer.transform(X_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
X_valid = torch.tensor(X_valid, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_valid = torch.tensor(y_valid, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_valid, y_valid)
train_loader = DataLoader(train_dataset,
                          batch_size=batch_size,
                          shuffle=True,                         
                         )
val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=True,
                       )

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        
    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        output = self.output(x)
        return output.squeeze(1)

# %%
class LinearRegression(nn.Module):
    def __init__(self, input_dims):
        super().__init__()
        self.linear = nn.Linear(input_dims, 1)
        
    def forward(self, x):
        x = self.linear(x)
        return x.squeeze(1)

# %%
class MLP_sigmoid(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        
    def forward(self, x):
        x = self.linear1(x)
        x = F.sigmoid(x)
        x = self.linear2(x)
        x = F.sigmoid(x)
        output = self.output(x)
        return output.squeeze(1)

# %%
class MLP_tanh(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)
        
    def forward(self, x):
        x = self.linear1(x)
        x = F.tanh(x)
        x = self.linear2(x)
        x = F.tanh(x)
        output = self.output(x)
        return output.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64

# model = LinearRegression(input_dims)
# model = MLP(input_dims, hidden_dims, output_dims)
# model = MLP_sigmoid(input_dims, hidden_dims, output_dims)
model = MLP_tanh(input_dims, hidden_dims, output_dims)

# %%
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_y = torch.mean(y_true)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    ss_tot = torch.sum((y_true - mean_y) ** 2)
    return 1 - (ss_res / ss_tot)

# %%
n_epochs = 100
lr = 0.01
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
train_losses = []
val_losses = []
train_r2s = []
val_r2s = []

# %%
for ep in range(n_epochs):
    train_loss = 0.0
    train_y_pred = []
    train_y_true = []
    val_y_pred = []
    val_y_true = []
    model.train()
    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)
        optimizer.zero_grad()
        output = model(X_batch)
        loss = criterion(output, y_batch)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_y_pred += output.tolist()
        train_y_true += y_batch.tolist()
    train_loss = train_loss / len(train_loader)
    train_r2 = r_squared(train_y_true, train_y_pred)
    train_losses.append(train_loss)
    train_r2s.append(train_r2)
    # evaluation:
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)
            output = model(X_batch)
            loss = criterion(output, y_batch)
            val_loss += loss.item()
            val_y_pred += output.tolist()
            val_y_true += y_batch.tolist()
        val_loss = val_loss / len(val_loader)
        val_r2 = r_squared(val_y_true, val_y_pred)     
    val_losses.append(val_loss)
    val_r2s.append(val_r2)
    print(f'EPOCH {ep + 1}: train_loss: {train_loss:.3f} || train_r2: {train_r2:.3f} || valid_loss: {val_loss:.3f} || valid_r2: {val_r2:.3f}')
# Out:
# EPOCH 1: train_loss: 263.972 || train_r2: -3.684 || valid_loss: 20.256 || valid_r2: 0.653
# EPOCH 2: train_loss: 28.253 || train_r2: 0.527 || valid_loss: 19.683 || valid_r2: 0.690
# EPOCH 3: train_loss: 19.658 || train_r2: 0.676 || valid_loss: 11.269 || valid_r2: 0.836
# EPOCH 4: train_loss: 15.033 || train_r2: 0.746 || valid_loss: 8.117 || valid_r2: 0.867
# EPOCH 5: train_loss: 11.706 || train_r2: 0.796 || valid_loss: 10.630 || valid_r2: 0.826
# EPOCH 6: train_loss: 11.586 || train_r2: 0.806 || valid_loss: 8.421 || valid_r2: 0.868
# EPOCH 7: train_loss: 10.905 || train_r2: 0.816 || valid_loss: 6.323 || valid_r2: 0.896
# EPOCH 8: train_loss: 9.247 || train_r2: 0.841 || valid_loss: 4.868 || valid_r2: 0.912
# EPOCH 9: train_loss: 9.412 || train_r2: 0.838 || valid_loss: 6.764 || valid_r2: 0.905
# EPOCH 10: train_loss: 8.427 || train_r2: 0.854 || valid_loss: 7.025 || valid_r2: 0.906
# EPOCH 11: train_loss: 8.798 || train_r2: 0.855 || valid_loss: 5.353 || valid_r2: 0.918
# EPOCH 12: train_loss: 8.981 || train_r2: 0.849 || valid_loss: 5.861 || valid_r2: 0.890
# EPOCH 13: train_loss: 8.513 || train_r2: 0.855 || valid_loss: 5.694 || valid_r2: 0.903
# EPOCH 14: train_loss: 8.607 || train_r2: 0.854 || valid_loss: 5.771 || valid_r2: 0.907
# EPOCH 15: train_loss: 9.267 || train_r2: 0.847 || valid_loss: 12.695 || valid_r2: 0.805
# EPOCH 16: train_loss: 9.460 || train_r2: 0.843 || valid_loss: 10.477 || valid_r2: 0.823
# EPOCH 17: train_loss: 7.916 || train_r2: 0.866 || valid_loss: 5.050 || valid_r2: 0.919
# EPOCH 18: train_loss: 7.949 || train_r2: 0.870 || valid_loss: 6.340 || valid_r2: 0.906
# EPOCH 19: train_loss: 9.031 || train_r2: 0.856 || valid_loss: 9.156 || valid_r2: 0.847
# EPOCH 20: train_loss: 8.549 || train_r2: 0.851 || valid_loss: 5.010 || valid_r2: 0.908
# EPOCH 21: train_loss: 7.529 || train_r2: 0.876 || valid_loss: 6.697 || valid_r2: 0.884
# EPOCH 22: train_loss: 7.582 || train_r2: 0.873 || valid_loss: 6.042 || valid_r2: 0.896
# EPOCH 23: train_loss: 7.507 || train_r2: 0.871 || valid_loss: 4.880 || valid_r2: 0.918
# EPOCH 24: train_loss: 7.469 || train_r2: 0.874 || valid_loss: 6.227 || valid_r2: 0.901
# EPOCH 25: train_loss: 7.210 || train_r2: 0.874 || valid_loss: 5.962 || valid_r2: 0.909
# EPOCH 26: train_loss: 6.829 || train_r2: 0.885 || valid_loss: 6.008 || valid_r2: 0.895
# EPOCH 27: train_loss: 7.061 || train_r2: 0.882 || valid_loss: 5.680 || valid_r2: 0.903
# EPOCH 28: train_loss: 6.899 || train_r2: 0.883 || valid_loss: 9.066 || valid_r2: 0.861
# EPOCH 29: train_loss: 6.852 || train_r2: 0.880 || valid_loss: 4.747 || valid_r2: 0.920
# EPOCH 30: train_loss: 8.118 || train_r2: 0.866 || valid_loss: 8.657 || valid_r2: 0.867
# EPOCH 31: train_loss: 6.753 || train_r2: 0.884 || valid_loss: 5.282 || valid_r2: 0.916
# EPOCH 32: train_loss: 6.899 || train_r2: 0.890 || valid_loss: 6.749 || valid_r2: 0.886
# EPOCH 33: train_loss: 6.703 || train_r2: 0.886 || valid_loss: 5.493 || valid_r2: 0.909
# EPOCH 34: train_loss: 7.021 || train_r2: 0.877 || valid_loss: 5.923 || valid_r2: 0.905
# EPOCH 35: train_loss: 6.424 || train_r2: 0.887 || valid_loss: 5.034 || valid_r2: 0.916
# EPOCH 36: train_loss: 6.295 || train_r2: 0.892 || valid_loss: 6.093 || valid_r2: 0.905
# EPOCH 37: train_loss: 7.293 || train_r2: 0.877 || valid_loss: 5.309 || valid_r2: 0.909
# EPOCH 38: train_loss: 6.327 || train_r2: 0.892 || valid_loss: 4.917 || valid_r2: 0.921
# EPOCH 39: train_loss: 6.535 || train_r2: 0.888 || valid_loss: 5.738 || valid_r2: 0.906
# EPOCH 40: train_loss: 6.337 || train_r2: 0.894 || valid_loss: 5.282 || valid_r2: 0.910
# EPOCH 41: train_loss: 7.360 || train_r2: 0.882 || valid_loss: 5.456 || valid_r2: 0.905
# EPOCH 42: train_loss: 6.272 || train_r2: 0.895 || valid_loss: 5.452 || valid_r2: 0.914
# EPOCH 43: train_loss: 6.183 || train_r2: 0.900 || valid_loss: 5.423 || valid_r2: 0.909
# EPOCH 44: train_loss: 6.054 || train_r2: 0.897 || valid_loss: 5.321 || valid_r2: 0.912
# EPOCH 45: train_loss: 6.851 || train_r2: 0.881 || valid_loss: 6.094 || valid_r2: 0.902
# EPOCH 46: train_loss: 5.732 || train_r2: 0.902 || valid_loss: 5.130 || valid_r2: 0.917
# EPOCH 47: train_loss: 6.354 || train_r2: 0.891 || valid_loss: 4.928 || valid_r2: 0.917
# EPOCH 48: train_loss: 6.152 || train_r2: 0.900 || valid_loss: 6.634 || valid_r2: 0.896
# EPOCH 49: train_loss: 5.857 || train_r2: 0.899 || valid_loss: 5.790 || valid_r2: 0.900
# EPOCH 50: train_loss: 6.349 || train_r2: 0.896 || valid_loss: 7.953 || valid_r2: 0.862
# EPOCH 51: train_loss: 6.909 || train_r2: 0.882 || valid_loss: 5.462 || valid_r2: 0.909
# EPOCH 52: train_loss: 6.491 || train_r2: 0.891 || valid_loss: 4.974 || valid_r2: 0.909
# EPOCH 53: train_loss: 5.665 || train_r2: 0.902 || valid_loss: 6.244 || valid_r2: 0.896
# EPOCH 54: train_loss: 5.927 || train_r2: 0.900 || valid_loss: 5.460 || valid_r2: 0.906
# EPOCH 55: train_loss: 5.795 || train_r2: 0.899 || valid_loss: 6.869 || valid_r2: 0.902
# EPOCH 56: train_loss: 6.201 || train_r2: 0.894 || valid_loss: 5.996 || valid_r2: 0.899
# EPOCH 57: train_loss: 6.297 || train_r2: 0.892 || valid_loss: 6.595 || valid_r2: 0.897
# EPOCH 58: train_loss: 5.917 || train_r2: 0.898 || valid_loss: 6.830 || valid_r2: 0.901
# EPOCH 59: train_loss: 5.856 || train_r2: 0.902 || valid_loss: 7.393 || valid_r2: 0.892
# EPOCH 60: train_loss: 6.012 || train_r2: 0.900 || valid_loss: 5.883 || valid_r2: 0.899
# EPOCH 61: train_loss: 5.519 || train_r2: 0.904 || valid_loss: 5.572 || valid_r2: 0.906
# EPOCH 62: train_loss: 6.159 || train_r2: 0.903 || valid_loss: 6.502 || valid_r2: 0.895
# EPOCH 63: train_loss: 5.646 || train_r2: 0.904 || valid_loss: 6.787 || valid_r2: 0.886
# EPOCH 64: train_loss: 6.657 || train_r2: 0.892 || valid_loss: 8.312 || valid_r2: 0.864
# EPOCH 65: train_loss: 5.611 || train_r2: 0.905 || valid_loss: 7.869 || valid_r2: 0.882
# EPOCH 66: train_loss: 5.716 || train_r2: 0.903 || valid_loss: 5.716 || valid_r2: 0.903
# EPOCH 67: train_loss: 5.708 || train_r2: 0.901 || valid_loss: 6.467 || valid_r2: 0.889
# EPOCH 68: train_loss: 6.256 || train_r2: 0.894 || valid_loss: 5.602 || valid_r2: 0.909
# EPOCH 69: train_loss: 5.490 || train_r2: 0.906 || valid_loss: 5.728 || valid_r2: 0.897
# EPOCH 70: train_loss: 5.738 || train_r2: 0.901 || valid_loss: 6.987 || valid_r2: 0.902
# EPOCH 71: train_loss: 5.589 || train_r2: 0.904 || valid_loss: 5.293 || valid_r2: 0.907
# EPOCH 72: train_loss: 5.591 || train_r2: 0.905 || valid_loss: 5.769 || valid_r2: 0.899
# EPOCH 73: train_loss: 5.513 || train_r2: 0.907 || valid_loss: 5.730 || valid_r2: 0.912
# EPOCH 74: train_loss: 5.439 || train_r2: 0.910 || valid_loss: 6.245 || valid_r2: 0.891
# EPOCH 75: train_loss: 6.188 || train_r2: 0.903 || valid_loss: 8.711 || valid_r2: 0.850
# EPOCH 76: train_loss: 5.643 || train_r2: 0.907 || valid_loss: 7.672 || valid_r2: 0.899
# EPOCH 77: train_loss: 5.565 || train_r2: 0.906 || valid_loss: 8.217 || valid_r2: 0.869
# EPOCH 78: train_loss: 5.610 || train_r2: 0.906 || valid_loss: 7.309 || valid_r2: 0.889
# EPOCH 79: train_loss: 5.503 || train_r2: 0.907 || valid_loss: 5.424 || valid_r2: 0.908
# EPOCH 80: train_loss: 5.243 || train_r2: 0.912 || valid_loss: 8.761 || valid_r2: 0.854
# EPOCH 81: train_loss: 5.887 || train_r2: 0.899 || valid_loss: 5.236 || valid_r2: 0.905
# EPOCH 82: train_loss: 5.233 || train_r2: 0.913 || valid_loss: 7.975 || valid_r2: 0.889
# EPOCH 83: train_loss: 5.599 || train_r2: 0.903 || valid_loss: 6.903 || valid_r2: 0.897
# EPOCH 84: train_loss: 5.586 || train_r2: 0.913 || valid_loss: 7.700 || valid_r2: 0.878
# EPOCH 85: train_loss: 5.586 || train_r2: 0.908 || valid_loss: 7.793 || valid_r2: 0.877
# EPOCH 86: train_loss: 5.559 || train_r2: 0.910 || valid_loss: 9.515 || valid_r2: 0.838
# EPOCH 87: train_loss: 5.656 || train_r2: 0.906 || valid_loss: 8.324 || valid_r2: 0.870
# EPOCH 88: train_loss: 5.536 || train_r2: 0.909 || valid_loss: 5.412 || valid_r2: 0.911
# EPOCH 89: train_loss: 5.126 || train_r2: 0.917 || valid_loss: 8.250 || valid_r2: 0.868
# EPOCH 90: train_loss: 5.500 || train_r2: 0.908 || valid_loss: 7.029 || valid_r2: 0.904
# EPOCH 91: train_loss: 5.264 || train_r2: 0.913 || valid_loss: 7.113 || valid_r2: 0.900
# EPOCH 92: train_loss: 5.350 || train_r2: 0.915 || valid_loss: 8.097 || valid_r2: 0.879
# EPOCH 93: train_loss: 6.329 || train_r2: 0.896 || valid_loss: 6.982 || valid_r2: 0.880
# EPOCH 94: train_loss: 5.300 || train_r2: 0.912 || valid_loss: 7.073 || valid_r2: 0.883
# EPOCH 95: train_loss: 4.684 || train_r2: 0.919 || valid_loss: 6.081 || valid_r2: 0.906
# EPOCH 96: train_loss: 5.033 || train_r2: 0.915 || valid_loss: 6.808 || valid_r2: 0.894
# EPOCH 97: train_loss: 5.347 || train_r2: 0.912 || valid_loss: 8.138 || valid_r2: 0.892
# EPOCH 98: train_loss: 4.851 || train_r2: 0.921 || valid_loss: 5.374 || valid_r2: 0.905
# EPOCH 99: train_loss: 5.474 || train_r2: 0.908 || valid_loss: 6.136 || valid_r2: 0.898
# EPOCH 100: train_loss: 4.875 || train_r2: 0.917 || valid_loss: 5.994 || valid_r2: 0.899

# %%
model.eval()
with torch.no_grad():
    y_hat = model(X_test)
    test_r2 = r_squared(y_test, y_hat)
    print('Evaluation on validation set:')
    print(f'R2: {test_r2}')
# Out:
# Evaluation on validation set:
# R2: 0.9111863374710083

# %%
# !pip install torch-summary
# Out:
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl.metadata (18 kB)
# Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5

# %%
# from torchsummary import summary
# summary(model, (1, 9))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Linear: 1-1                            [-1, 1, 1]                10
# ==========================================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Linear: 1-1                            [-1, 1, 1]                10
# ==========================================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# Total mult-adds (M): 0.00
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ==========================================================================================
